# %% [markdown]
# # Weather features

# %% [markdown]
# ## Bidding zone

# %% [markdown]
# Northern Europe bidding zones, with DK1 being continental Denmark

# %%
from IPython.display import Image
import pandas as pd

Image(filename = "/Users/vingtcoeurs/Downloads/Northern EU biddig zones.png", width = 440, height = 300)

# %% [markdown]
# More details below

# %%
Image(filename = "/Users/vingtcoeurs/Downloads/DK bidding zones.png", width = 400, height = 300)

# %% [markdown]
# __The limit between DK1 and DK2 is Stor-Balt bridge. We added a red line to show the boundary__

# %%
Image(filename = "/Users/vingtcoeurs/Downloads/NO-DK bidding zones.png", width = 900, height = 300)

# %% [markdown]
#  In terms of administrative regions, DK1 covers:
#  Nordjylland
#  Midtjylland
#  Syddanmark

# %%
Image(filename = "/Users/vingtcoeurs/Downloads/Denmark_regions.png", width = 400, height = 300)

# %%
data = {'Name':['North Jutland', 'Central Jutland', 'Southern Denmark'], 
        'total_pop':[589936, 1326340,1223105]} 
regions = pd.DataFrame(data,)
regions
# Out:
#                Name  total_pop
# 0     North Jutland     589936
# 1   Central Jutland    1326340
# 2  Southern Denmark    1223105

# %%
regions["share_of_bz_pop"]=100*regions["total_pop"]/regions["total_pop"].sum()
regions
# Out:
#                Name  total_pop  share_of_bz_pop
# 0     North Jutland     589936        18.791475
# 1   Central Jutland    1326340        42.248456
# 2  Southern Denmark    1223105        38.960069

# %% [markdown]
# ## Choice of cities

# %% [markdown]
# __DK1 represents 54% of total population in Denmark<br>
# Our sample of 11 cities represents__
# - 49% of DK1 total pop.
# - 26% of total Denmark pop (and 39% of total pop. excluding Copenhagen)

# %%
Image(filename = "/Users/vingtcoeurs/Downloads/Top 11 cities DK1.png", width = 800, height = 300)
